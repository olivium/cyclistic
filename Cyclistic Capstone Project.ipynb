# %%
import pandas as pd
import numpy as np
import datetime as dt
import gc

# %% [markdown]
# # Setup Data

# %%
#load original .csv files, a years worth of data from January 2022 to December 2022 and set 'ended_at' and 'started_at' to datetime type

jan01_df = pd.read_csv('202201-divvy-tripdata.csv', parse_dates = ['started_at','ended_at'], date_format = '%Y-%m-%d %H:%M:%S')
feb02_df = pd.read_csv('202202-divvy-tripdata.csv', parse_dates = ['started_at','ended_at'], date_format = '%Y-%m-%d %H:%M:%S')
mar03_df = pd.read_csv('202203-divvy-tripdata.csv', parse_dates = ['started_at','ended_at'], date_format = '%Y-%m-%d %H:%M:%S')
apr04_df = pd.read_csv('202204-divvy-tripdata.csv', parse_dates = ['started_at','ended_at'], date_format = '%Y-%m-%d %H:%M:%S')
may05_df = pd.read_csv('202205-divvy-tripdata.csv', parse_dates = ['started_at','ended_at'], date_format = '%Y-%m-%d %H:%M:%S')
jun06_df = pd.read_csv('202206-divvy-tripdata.csv', parse_dates = ['started_at','ended_at'], date_format = '%Y-%m-%d %H:%M:%S')
jul07_df = pd.read_csv('202207-divvy-tripdata.csv', parse_dates = ['started_at','ended_at'], date_format = '%Y-%m-%d %H:%M:%S')
aug08_df = pd.read_csv('202208-divvy-tripdata.csv', parse_dates = ['started_at','ended_at'], date_format = '%Y-%m-%d %H:%M:%S')
sep09_df = pd.read_csv('202209-divvy-tripdata.csv', parse_dates = ['started_at','ended_at'], date_format = '%Y-%m-%d %H:%M:%S')
oct10_df = pd.read_csv('202210-divvy-tripdata.csv', parse_dates = ['started_at','ended_at'], date_format = '%Y-%m-%d %H:%M:%S')
nov11_df = pd.read_csv('202211-divvy-tripdata.csv', parse_dates = ['started_at','ended_at'], date_format = '%Y-%m-%d %H:%M:%S')
dec12_df = pd.read_csv('202212-divvy-tripdata.csv', parse_dates = ['started_at','ended_at'], date_format = '%Y-%m-%d %H:%M:%S')

# %%
#merge all of the data frames into one year view

cyclistic_df = pd.concat([jan01_df,feb02_df,mar03_df,apr04_df,may05_df,jun06_df,jul07_df,aug08_df,sep09_df,oct10_df,nov11_df,dec12_df])

# %%
#remove individual month data frames to clear up space in the environment 

del [[jan01_df,feb02_df,mar03_df,apr04_df,may05_df,jun06_df,jul07_df,aug08_df,sep09_df,oct10_df,nov11_df,dec12_df]]
gc.collect()
# Out:
# 0

# %%
#create new data frame to contain new columns

cyclistic2022 = cyclistic_df

# %%
#calculate ride length by subtracting ended_at time from started_at time and converted it to minutes

cyclistic2022['ride_length'] = (cyclistic2022['ended_at']-cyclistic2022['started_at']) / dt.timedelta(minutes=1)
cyclistic2022['ride_length'] = cyclistic2022['ride_length'].round(decimals = 1)

# %%
cyclistic2022['date'] = cyclistic2022['started_at'].dt.date #create column for date-default format is yyyy-mm-dd

# %%
cyclistic2022['day_of_week'] = cyclistic2022['started_at'].dt.day_name() #create column for day of the week

# %%
cyclistic2022['year'] = cyclistic2022['started_at'].dt.year #create column for year

# %%
cyclistic2022['month'] = cyclistic2022['started_at'].dt.month_name() #create column for month

# %%
cyclistic2022['day'] = cyclistic2022['started_at'].dt.day #create column for day of the month

# %%
cyclistic2022['hour'] = cyclistic2022['started_at'].dt.hour #create new column for hour

# %%
#create column for different time_of_day: Night, Morning, Afternoon, Evening

cyclistic2022['time_of_day'] = (cyclistic2022['hour'] % 24 + 6) // 6
cyclistic2022['time_of_day'].replace({1: 'Night',
                                      2: 'Morning',
                                      3: 'Afternoon',
                                      4: 'Evening'}, inplace=True)

# %%
#create column for different seasons: Spring, Summer, Fall, Winter

seasons = {'January': 'Winter',
           'February': 'Winter',
           'March': 'Spring', 
           'April': 'Spring',
           'May': 'Spring',
           'June': 'Summer',
           'July': 'Summer',
           'August': 'Summer',
           'September': 'Fall',
           'October': 'Fall',
           'November': 'Fall',
           'December': 'Winter'}
cyclistic2022['season'] = cyclistic2022['month'].apply(lambda x: seasons[x])

# %% [markdown]
# # Clean the data

# %%
#remove rows with NA values
cyclistic2022 = cyclistic2022.dropna(axis=0, how='any')

# %%
#remove duplicate rows 
cyclistic2022 = cyclistic2022.drop_duplicates()

# %%
#remove rows where ride_length is 0 or negative
cyclistic2022 = cyclistic2022[~(cyclistic2022['ride_length']<=0)]

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ###### TOTAL RIDES

# %%
#total number of rides
len(cyclistic2022)
# Out:
# 4362089

# %% [markdown]
# ###### MEMBER TYPE

# %%
#total number of rides
cyclistic2022.groupby(['member_casual'])['member_casual'].count()
# Out:
# member_casual
# casual    1756025
# member    2606064
# Name: member_casual, dtype: int64

# %% [markdown]
# ###### TYPE OF BIKE

# %%
#total rides by member type 
cyclistic2022.groupby(['member_casual', 'rideable_type'])['rideable_type'].count()
# Out:
# member_casual  rideable_type
# casual         classic_bike      887583
#                docked_bike       174690
#                electric_bike     693752
# member         classic_bike     1705389
#                electric_bike     900675
# Name: rideable_type, dtype: int64

# %%
#total rides
cyclistic2022.groupby(['rideable_type'])['rideable_type'].count()
# Out:
# rideable_type
# classic_bike     2592972
# docked_bike       174690
# electric_bike    1594427
# Name: rideable_type, dtype: int64

# %% [markdown]
# ###### RIDING HOUR

# %%
#total rides by member type 
cyclistic2022.groupby(['member_casual','hour'])['hour'].count()
# Out:
# member_casual  hour
# casual         0        33270
#                1        21290
#                2        12647
#                3         7192
#                4         4653
#                5         8413
#                6        21658
#                7        37818
#                8        52182
#                9        54557
#                10       72269
#                11       94603
#                12      111547
#                13      115790
#                14      122570
#                15      135398
#                16      151838
#                17      169653
#                18      150044
#                19      113927
#                20       82984
#                21       71080
#                22       63798
#                23       46844
# member         0        25164
#                1        15517
#                2         8575
#                3         5236
#                4         6148
#                5        26050
#                6        75753
#                7       143004
#                8       166734
#                9       112234
#                10      103953
#                11      124701
#                12      143801
#                13      141336
#                14      140950
#                15      171716
#                16      232175
#                17      280697
#                18      223296
#                19      159249
#                20      110216
#                21       85261
#                22       63771
#                23       40527
# Name: hour, dtype: int64

# %%
#total rides
cyclistic2022.groupby(['hour'])['hour'].count()
# Out:
# hour
# 0      58434
# 1      36807
# 2      21222
# 3      12428
# 4      10801
# 5      34463
# 6      97411
# 7     180822
# 8     218916
# 9     166791
# 10    176222
# 11    219304
# 12    255348
# 13    257126
# 14    263520
# 15    307114
# 16    384013
# 17    450350
# 18    373340
# 19    273176
# 20    193200
# 21    156341
# 22    127569
# 23     87371
# Name: hour, dtype: int64

# %% [markdown]
# ###### TIME OF DAY

# %%
#morning
cyclistic2022.groupby(['member_casual','time_of_day']).apply(lambda x: x[x['time_of_day'] == 'Morning' ]['time_of_day'].count())
# Out:
# member_casual  time_of_day
# casual         Afternoon           0
#                Evening             0
#                Morning        333087
#                Night               0
# member         Afternoon           0
#                Evening             0
#                Morning        726379
#                Night               0
# dtype: int64

# %%
#total rides by member type
cyclistic2022.groupby(['member_casual','time_of_day'])['time_of_day'].count()
# Out:
# member_casual  time_of_day
# casual         Afternoon       806796
#                Evening         528677
#                Morning         333087
#                Night            87465
# member         Afternoon      1110675
#                Evening         682320
#                Morning         726379
#                Night            86690
# Name: time_of_day, dtype: int64

# %%
#total rides
cyclistic2022.groupby('time_of_day')['time_of_day'].count()
# Out:
# time_of_day
# Afternoon    1917471
# Evening      1210997
# Morning      1059466
# Night         174155
# Name: time_of_day, dtype: int64

# %% [markdown]
#  ###### DAY OF THE WEEK

# %%
#total rides by member type
cyclistic2022.groupby(['member_casual','day_of_week'])['day_of_week'].count()
# Out:
# member_casual  day_of_week
# casual         Friday         248479
#                Monday         210524
#                Saturday       366905
#                Sunday         300902
#                Thursday       229742
#                Tuesday        196146
#                Wednesday      203327
# member         Friday         359317
#                Monday         374454
#                Saturday       337540
#                Sunday         297082
#                Thursday       415145
#                Tuesday        410516
#                Wednesday      412010
# Name: day_of_week, dtype: int64

# %%
#total rides
cyclistic2022.groupby('day_of_week')['day_of_week'].count()
# Out:
# day_of_week
# Friday       607796
# Monday       584978
# Saturday     704445
# Sunday       597984
# Thursday     644887
# Tuesday      606662
# Wednesday    615337
# Name: day_of_week, dtype: int64

# %% [markdown]
# ###### DAY OF THE MONTH

# %%
#total rides by member type
cyclistic2022.groupby(['member_casual','day'])['day'].count()
# Out:
# member_casual  day
# casual         1      53871
#                2      59223
#                3      61620
#                4      55036
#                5      61430
#                       ...
# member         27     80999
#                28     88841
#                29     87875
#                30     78879
#                31     51729
# Name: day, Length: 62, dtype: int64

# %%
#total rides
cyclistic2022.groupby('day')['day'].count()
# Out:
# day
# 1     144149
# 2     146697
# 3     142808
# 4     136164
# 5     143856
# 6     127802
# 7     131018
# 8     125177
# 9     163444
# 10    168359
# 11    136530
# 12    142998
# 13    148295
# 14    153602
# 15    128971
# 16    158081
# 17    141959
# 18    132487
# 19    142756
# 20    142129
# 21    155690
# 22    144294
# 23    160405
# 24    138341
# 25    110967
# 26    138309
# 27    129481
# 28    147356
# 29    152363
# 30    143134
# 31     84467
# Name: day, dtype: int64

# %% [markdown]
# ###### MONTH

# %%
#total rides by member type
cyclistic2022.groupby(['member_casual','month'])['month'].count()
# Out:
# member_casual  month
# casual         April         91814
#                August       269768
#                December      31473
#                February      15125
#                January       12583
#                July         311280
#                June         291682
#                March         67089
#                May          219955
#                November      73451
#                October      151152
#                September    220653
# member         April        180349
#                August       334594
#                December     103673
#                February      73858
#                January       67411
#                July         330325
#                June         327612
#                March        148551
#                May          281723
#                November     181877
#                October      262415
#                September    313676
# Name: month, dtype: int64

# %%
#total rides
cyclistic2022.groupby('month')['month'].count()
# Out:
# month
# April        272163
# August       604362
# December     135146
# February      88983
# January       79994
# July         641605
# June         619294
# March        215640
# May          501678
# November     255328
# October      413567
# September    534329
# Name: month, dtype: int64

# %% [markdown]
# ###### SEASON

# %%
#total rides by member type
cyclistic2022.groupby(['member_casual','season'])['season'].count()
# Out:
# member_casual  season
# casual         Fall      445256
#                Spring    378858
#                Summer    872730
#                Winter     59181
# member         Fall      757968
#                Spring    610623
#                Summer    992531
#                Winter    244942
# Name: season, dtype: int64

# %%
#total rides
cyclistic2022.groupby('season')['season'].count()
# Out:
# season
# Fall      1203224
# Spring     989481
# Summer    1865261
# Winter     304123
# Name: season, dtype: int64

# %% [markdown]
# ###### AVERAGE RIDE DURATION

# %%
#average ride length
cyclistic2022['avg_ride_duration'] = cyclistic2022['ride_length'].mean()

# %%
#------------------MEMBER TYPE--------------------

# %%
#average ride length by member type
cyclistic2022.groupby('member_casual')['ride_length'].mean()
# Out:
# member_casual
# casual    24.022085
# member    12.475948
# Name: ride_length, dtype: float64

# %%
#----------------TYPE OF BIKE---------------------

# %%
#average ride length by member type
cyclistic2022.groupby(['member_casual','rideable_type'])['ride_length'].mean()
# Out:
# member_casual  rideable_type
# casual         classic_bike     24.479195
#                docked_bike      50.756575
#                electric_bike    16.705392
# member         classic_bike     13.258987
#                electric_bike    10.993298
# Name: ride_length, dtype: float64

# %%
#average ride length
cyclistic2022.groupby('rideable_type')['ride_length'].mean()
# Out:
# rideable_type
# classic_bike     17.099702
# docked_bike      50.756575
# electric_bike    13.478690
# Name: ride_length, dtype: float64

# %%
#-----------------------HOUR-------------------------

# %%
#average ride length by member type
cyclistic2022.groupby(['member_casual','hour'])['ride_length'].mean()
# Out:
# member_casual  hour
# casual         0       21.238972
#                1       24.078436
#                2       22.479434
#                3       22.023401
#                4       19.706641
#                5       16.557221
#                6       17.089196
#                7       15.448014
#                8       17.957175
#                9       23.866673
#                10      28.269921
#                11      28.529069
#                12      27.758455
#                13      28.100262
#                14      27.732752
#                15      26.367561
#                16      24.176692
#                17      22.384709
#                18      22.289887
#                19      22.797147
#                20      22.109052
#                21      20.908687
#                22      20.384547
#                23      21.432030
# member         0       12.446396
#                1       12.335290
#                2       12.417073
#                3       12.274503
#                4       12.490924
#                5       10.355044
#                6       10.847176
#                7       11.389395
#                8       11.180515
#                9       11.463079
#                10      12.270087
#                11      12.590466
#                12      12.272986
#                13      12.502810
#                14      12.855313
#                15      12.751557
#                16      12.962265
#                17      13.244459
#                18      13.180642
#                19      12.992038
#                20      12.789164
#                21      12.467607
#                22      12.407364
#                23      12.529832
# Name: ride_length, dtype: float64

# %%
#average ride length
cyclistic2022.groupby('hour')['ride_length'].mean()
# Out:
# hour
# 0     17.452540
# 1     19.127791
# 2     18.413618
# 3     17.916125
# 4     15.599407
# 5     11.869100
# 6     12.235003
# 7     12.238234
# 8     12.795836
# 9     15.520270
# 10    18.831652
# 11    19.466034
# 12    19.037705
# 13    19.526716
# 14    19.775197
# 15    18.754474
# 16    17.396428
# 17    16.687716
# 18    16.841615
# 19    17.081221
# 20    16.792278
# 21    16.305320
# 22    16.396799
# 23    17.302749
# Name: ride_length, dtype: float64

# %%
#--------------------TIME OF DAY---------------------

# %%
#average ride length by member type
cyclistic2022.groupby(['member_casual','time_of_day'])['ride_length'].mean()
# Out:
# member_casual  time_of_day
# casual         Afternoon      25.766109
#                Evening        21.879175
#                Morning        23.823928
#                Night          21.642155
# member         Afternoon      12.839725
#                Evening        12.873360
#                Morning        11.628517
#                Night          11.787941
# Name: ride_length, dtype: float64

# %%
#average ride length
cyclistic2022.groupby('time_of_day')['ride_length'].mean()
# Out:
# time_of_day
# Afternoon    18.278636
# Evening      16.804970
# Morning      15.462649
# Night        16.736974
# Name: ride_length, dtype: float64

# %%
#-------------------DAY OF THE WEEK-----------------

# %%
#average ride length by member type

# %%
cyclistic2022.groupby(['member_casual','day_of_week'])['ride_length'].mean()
# Out:
# member_casual  day_of_week
# casual         Friday         22.385639
#                Monday         24.861576
#                Saturday       26.797757
#                Sunday         27.263099
#                Thursday       21.427891
#                Tuesday        21.467381
#                Wednesday      20.743350
# member         Friday         12.252003
#                Monday         12.055691
#                Saturday       14.011964
#                Sunday         13.880579
#                Thursday       12.053272
#                Tuesday        11.811992
#                Wednesday      11.869442
# Name: ride_length, dtype: float64

# %%
#average ride length
cyclistic2022.groupby('day_of_week')['ride_length'].mean()
# Out:
# day_of_week
# Friday       16.394833
# Monday       16.664319
# Saturday     20.671350
# Sunday       20.614584
# Thursday     15.392995
# Tuesday      14.933773
# Wednesday    14.801665
# Name: ride_length, dtype: float64

# %%
#-------------------DAY OF THE WEEK-----------------

# %%
#average ride_length by member type
cyclistic2022.groupby(['member_casual','day'])['ride_length'].mean()
# Out:
# member_casual  day
# casual         1      22.480030
#                2      24.334360
#                3      25.073064
#                4      24.432050
#                5      26.074656
#                         ...
# member         27     12.000946
#                28     12.218706
#                29     12.496026
#                30     12.799615
#                31     12.599789
# Name: ride_length, Length: 62, dtype: float64

# %%
#average ride_length
cyclistic2022.groupby('day')['ride_length'].mean()
# Out:
# day
# 1     16.011877
# 2     17.254835
# 3     17.909547
# 4     17.279291
# 5     18.397281
# 6     16.179607
# 7     15.572170
# 8     15.076569
# 9     18.161980
# 10    18.307197
# 11    16.921493
# 12    16.888982
# 13    17.184369
# 14    17.556464
# 15    16.077807
# 16    17.764325
# 17    16.977298
# 18    17.041338
# 19    17.081790
# 20    16.787147
# 21    17.086677
# 22    17.120672
# 23    18.984603
# 24    17.418144
# 25    15.980109
# 26    16.787319
# 27    15.889792
# 28    16.877715
# 29    17.548704
# 30    18.273825
# 31    16.518812
# Name: ride_length, dtype: float64

# %%
#---------------------MONTH--------------------------

# %%
#average ride_length by member type
cyclistic2022.groupby(['member_casual','month'])['ride_length'].mean()
# Out:
# member_casual  month
# casual         April        25.970226
#                August       23.312170
#                December     14.855635
#                February     24.854737
#                January      27.403028
#                July         25.124696
#                June         25.051989
#                March        28.464440
#                May          27.741445
#                November     17.265953
#                October      20.490996
#                September    21.829642
# member         April        11.629643
#                August       13.130560
#                December     10.222489
#                February     10.669940
#                January      10.286968
#                July         13.530695
#                June         13.711550
#                March        11.818241
#                May          13.328030
#                November     10.848018
#                October      11.698341
#                September    12.644139
# Name: ride_length, dtype: float64

# %%
#average ride_length
cyclistic2022.groupby('month')['ride_length'].mean()
# Out:
# month
# April        16.467429
# August       17.675308
# December     11.301463
# February     13.081019
# January      12.979312
# July         19.155621
# June         19.052797
# March        16.997136
# May          19.647427
# November     12.694285
# October      14.911913
# September    16.437324
# Name: ride_length, dtype: float64

# %%
#----------------------SEASON-------------------------

# %%
#average ride_length by member type
cyclistic2022.groupby(['member_casual','season'])['ride_length'].mean()
# Out:
# member_casual  season
# casual         Fall      20.622367
#                Spring    27.440230
#                Summer    24.540130
#                Winter    20.078937
# member         Fall      11.885710
#                Spring    12.459109
#                Summer    13.455501
#                Winter    10.375155
# Name: ride_length, dtype: float64

# %%
#average ride_length by member type
cyclistic2022.groupby('season')['ride_length'].mean()
# Out:
# season
# Fall      15.118731
# Spring    18.195164
# Summer    18.641846
# Winter    12.263469
# Name: ride_length, dtype: float64

# %%
cyclistic2022.head(50)
# Out:
#              ride_id  rideable_type          started_at            ended_at  \
# 0   C2F7DD78E82EC875  electric_bike 2022-01-13 11:59:47 2022-01-13 12:02:44
# 1   A6CF8980A652D272  electric_bike 2022-01-10 08:41:56 2022-01-10 08:46:17
# 2   BD0F91DFF741C66D   classic_bike 2022-01-25 04:53:40 2022-01-25 04:58:01
# 3   CBB80ED419105406   classic_bike 2022-01-04 00:18:04 2022-01-04 00:33:00
# 4   DDC963BFDDA51EEA   classic_bike 2022-01-20 01:31:10 2022-01-20 01:37:12
# 5   A39C6F6CC0586C0B   classic_bike 2022-01-11 18:48:09 2022-01-11 18:51:31
# 6   BDC4AB637EDF981B   classic_bike 2022-01-30 18:32:52 2022-01-30 18:49:26
# 7   81751A3186E59A6B   classic_bike 2022-01-22 12:20:02 2022-01-22 12:32:06
# 8   154222B86A338ABD  electric_bike 2022-01-17 07:34:41 2022-01-17 08:00:08
# 9   72DC25B2DD467EEF   classic_bike 2022-01-28 15:27:53 2022-01-28 15:35:16
# 10  F20394FE09C63DB2   classic_bike 2022-01-11 18:27:59 2022-01-11 18:34:20
# 11  006D3F363CF9600B  electric_bike 2022-01-29 12:30:43 2022-01-29 12:43:04
# 12  FB258EEBE89F4E17   classic_bike 2022-01-02 17:56:18 2022-01-02 18:05:38
# 13  2EF51270B08DEE03   classic_bike 2022-01-20 22:03:06 2022-01-20 22:09:59
# 14  E119D4E6BF686601  electric_bike 2022-01-08 05:36:40 2022-01-08 05:46:40
# 15  7DD70C4AA0F3EA7B   classic_bike 2022-01-14 05:47:07 2022-01-14 05:47:39
# 16  0AA241497B970400   classic_bike 2022-01-12 14:09:13 2022-01-12 14:10:53
# 17  F5E6D97D85BE8039   classic_bike 2022-01-31 12:07:45 2022-01-31 12:12:48
# 18  78168928DF06A497   classic_bike 2022-01-28 17:21:59 2022-01-28 17:26:54
# 19  15C176B55C2BC059   classic_bike 2022-01-19 21:00:40 2022-01-19 21:09:56
# 20  12D2B5AA545EF922   classic_bike 2022-01-24 15:19:37 2022-01-24 15:45:27
# 21  1A185AF405E7B2DB   classic_bike 2022-01-13 12:47:10 2022-01-13 13:10:20
# 22  9D4AAF43A011FC59  electric_bike 2022-01-18 08:03:16 2022-01-18 08:08:00
# 23  A209F8E0E84D49B4   classic_bike 2022-01-25 14:46:24 2022-01-25 15:00:27
# 24  6D6B462903DCB23F  electric_bike 2022-01-10 06:44:21 2022-01-10 06:51:28
# 25  DC809CD3B3F3BFC9   classic_bike 2022-01-22 15:14:32 2022-01-22 15:25:21
# 26  1C2362DAD4090D8A  electric_bike 2022-01-03 00:12:42 2022-01-03 00:17:50
# 27  AB4032C2B151D137   classic_bike 2022-01-31 18:58:30 2022-01-31 19:05:17
# 28  E6B6D4531ADC9F52   classic_bike 2022-01-15 17:41:15 2022-01-15 17:48:54
# 29  81B423963BA2C10C   classic_bike 2022-01-24 10:15:53 2022-01-24 10:39:53
# 30  EC80F318604595AE  electric_bike 2022-01-27 17:54:41 2022-01-27 18:05:24
# 31  80F0735AD7F23AD9  electric_bike 2022-01-18 17:52:46 2022-01-18 18:18:40
# 32  59E50C91451F529C   classic_bike 2022-01-27 11:58:14 2022-01-27 12:07:43
# 33  2A23ED3FECB72E5B  electric_bike 2022-01-15 12:52:14 2022-01-15 12:59:42
# 34  88543D9BC6760955   classic_bike 2022-01-14 10:14:38 2022-01-14 10:27:07
# 35  E38E5318BDBC139A   classic_bike 2022-01-13 16:41:02 2022-01-13 16:55:49
# 36  A184D11FDF48937A   classic_bike 2022-01-12 16:39:28 2022-01-12 16:53:00
# 37  1EFB6377FE801DEF   classic_bike 2022-01-29 06:29:53 2022-01-29 06:32:32
# 38  0A5CD4848EB8CFE8  electric_bike 2022-01-12 22:32:48 2022-01-12 22:41:56
# 39  74D8B5BC10B9E223   classic_bike 2022-01-19 12:31:28 2022-01-19 12:34:08
# 40  3C07A7C383512251   classic_bike 2022-01-04 15:08:21 2022-01-04 15:11:06
# 41  40C9DFE4CFB178A3   classic_bike 2022-01-20 16:56:41 2022-01-20 17:13:38
# 42  04EC503AB7123CCE   classic_bike 2022-01-22 15:33:10 2022-01-22 15:48:54
# 43  ABA3DE288B9D9A10   classic_bike 2022-01-12 09:49:49 2022-01-12 10:28:50
# 44  007070F5088EB3C0   classic_bike 2022-01-04 09:16:39 2022-01-04 09:24:27
# 45  7117CF2AEFF29287   classic_bike 2022-01-19 16:39:30 2022-01-19 16:46:41
# 46  A3DCFB423064F830   classic_bike 2022-01-02 16:05:40 2022-01-02 16:19:05
# 47  145739172978E774   classic_bike 2022-01-13 12:54:21 2022-01-13 12:58:50
# 48  1EBF95B25BB5091A   classic_bike 2022-01-17 10:53:26 2022-01-17 11:05:48
# 49  060598F8DA7E017B   classic_bike 2022-01-26 15:53:41 2022-01-26 15:55:12
#
#                start_station_name start_station_id  \
# 0        Glenwood Ave & Touhy Ave              525
# 1        Glenwood Ave & Touhy Ave              525
# 2   Sheffield Ave & Fullerton Ave     TA1306000016
# 3        Clark St & Bryn Mawr Ave     KA1504000151
# 4     Michigan Ave & Jackson Blvd     TA1309000002
# 5           Wood St & Chicago Ave              637
# 6     Oakley Ave & Irving Park Rd     KA1504000158
# 7   Sheffield Ave & Fullerton Ave     TA1306000016
# 8            Racine Ave & 15th St            13304
# 9       LaSalle St & Jackson Blvd     TA1309000004
# 10      LaSalle St & Jackson Blvd     TA1309000004
# 11     Clarendon Ave & Leland Ave     TA1307000119
# 12  Sheffield Ave & Fullerton Ave     TA1306000016
# 13          Rush St & Superior St            15530
# 14    Michigan Ave & Jackson Blvd     TA1309000002
# 15      Lincoln Park Conservatory              LP-
# 16      LaSalle St & Jackson Blvd     TA1309000004
# 17    Michigan Ave & Jackson Blvd     TA1309000002
# 18    Michigan Ave & Jackson Blvd     TA1309000002
# 19       Clark St & Bryn Mawr Ave     KA1504000151
# 20      Lincoln Park Conservatory              LP-
# 21        Sedgwick St & North Ave     TA1307000038
# 22    California Ave & Altgeld St            15646
# 23  Sheffield Ave & Fullerton Ave     TA1306000016
# 24           Racine Ave & 15th St            13304
# 25          Indiana Ave & 31st St     TA1308000036
# 26          Indiana Ave & 31st St     TA1308000036
# 27        Lake Park Ave & 56th St     TA1309000063
# 28  Sheffield Ave & Fullerton Ave     TA1306000016
# 29      Lincoln Park Conservatory              LP-
# 30     Sheridan Rd & Montrose Ave     TA1307000107
# 31       Clark St & Bryn Mawr Ave     KA1504000151
# 32         State St & Harrison St           SL-007
# 33   Halsted St & North Branch St     KA1504000117
# 34    Michigan Ave & Jackson Blvd     TA1309000002
# 35       Glenwood Ave & Touhy Ave              525
# 36       Glenwood Ave & Touhy Ave              525
# 37       Glenwood Ave & Touhy Ave              525
# 38   Washtenaw Ave & Lawrence Ave     KA1504000080
# 39       Glenwood Ave & Touhy Ave              525
# 40       Glenwood Ave & Touhy Ave              525
# 41         State St & Harrison St           SL-007
# 42       University Ave & 57th St     KA1503000071
# 43       Glenwood Ave & Touhy Ave              525
# 44    Michigan Ave & Jackson Blvd     TA1309000002
# 45      LaSalle St & Jackson Blvd     TA1309000004
# 46      Halsted St & Clybourn Ave              331
# 47           Clinton St & Lake St            13021
# 48           Racine Ave & 15th St            13304
# 49          Evanston Civic Center              661
#
#                        end_station_name end_station_id  start_lat  start_lng  \
# 0                  Clark St & Touhy Ave         RP-007  42.012800 -87.665906
# 1                  Clark St & Touhy Ave         RP-007  42.012763 -87.665967
# 2         Greenview Ave & Fullerton Ave   TA1307000001  41.925602 -87.653708
# 3             Paulina St & Montrose Ave   TA1309000021  41.983593 -87.669154
# 4                State St & Randolph St   TA1305000029  41.877850 -87.624080
# 5               Honore St & Division St   TA1305000034  41.895634 -87.672069
# 6                Broadway & Sheridan Rd          13323  41.954341 -87.686080
# 7              Damen Ave & Clybourn Ave          13271  41.925602 -87.653708
# 8          Clinton St & Washington Blvd         WL-012  41.861251 -87.656500
# 9          Clinton St & Washington Blvd         WL-012  41.878166 -87.631929
# 10         Clinton St & Washington Blvd         WL-012  41.878166 -87.631929
# 11             Broadway & Granville Ave          15571  41.967962 -87.650029
# 12         Stockton Dr & Wrightwood Ave          13276  41.925602 -87.653708
# 13           Larrabee St & Kingsbury St   TA1306000009  41.895765 -87.625908
# 14               St. Clair St & Erie St          13016  41.877849 -87.624056
# 15            Lincoln Park Conservatory            LP-  41.923931 -87.635825
# 16            Clark St & Ida B Wells Dr   TA1305000009  41.878166 -87.631929
# 17           Indiana Ave & Roosevelt Rd         SL-005  41.877850 -87.624080
# 18           Indiana Ave & Roosevelt Rd         SL-005  41.877850 -87.624080
# 19             Clark St & Schreiber Ave   KA1504000156  41.983593 -87.669154
# 20         Michigan Ave & Washington St          13001  41.923931 -87.635825
# 21              Sedgwick St & North Ave   TA1307000038  41.911386 -87.638677
# 22          Milwaukee Ave & Rockwell St          13242  41.926648 -87.697661
# 23               Halsted St & Roscoe St   TA1309000025  41.925602 -87.653708
# 24                Wolcott Ave & Polk St   TA1309000064  41.861207 -87.656600
# 25                Emerald Ave & 31st St   TA1309000055  41.838842 -87.621857
# 26                Indiana Ave & 40th St          13083  41.838817 -87.621835
# 27                   Shore Dr & 55th St   TA1308000009  41.793242 -87.587782
# 28         Ashland Ave & Wrightwood Ave          13296  41.925602 -87.653708
# 29                   Daley Center Plaza   TA1306000010  41.923931 -87.635825
# 30         Southport Ave & Waveland Ave          13235  41.961647 -87.654632
# 31             Elston Ave & Cortland St   TA1305000039  41.983563 -87.669156
# 32                   Clark St & Lake St   KA1503000012  41.874053 -87.627716
# 33               Clark St & Chicago Ave          13303  41.899331 -87.648567
# 34  Orleans St & Merchandise Mart Plaza   TA1305000022  41.877850 -87.624080
# 35             Clark St & Bryn Mawr Ave   KA1504000151  42.012701 -87.666058
# 36             Clark St & Bryn Mawr Ave   KA1504000151  42.012701 -87.666058
# 37           Greenview Ave & Jarvis Ave            520  42.012701 -87.666058
# 38          Western Ave & Granville Ave   KA1504000129  41.968747 -87.696182
# 39             Glenwood Ave & Morse Ave   KA1504000175  42.012701 -87.666058
# 40             Glenwood Ave & Morse Ave   KA1504000175  42.012701 -87.666058
# 41               Sedgwick St & Huron St   TA1307000062  41.874053 -87.627716
# 42              Lake Park Ave & 47th St   TA1308000035  41.791478 -87.599861
# 43         Southport Ave & Clybourn Ave   TA1309000030  42.012701 -87.666058
# 44            Clinton St & Jackson Blvd            638  41.877850 -87.624080
# 45         Desplaines St & Jackson Blvd          15539  41.878166 -87.631929
# 46        Greenview Ave & Fullerton Ave   TA1307000001  41.909668 -87.648128
# 47         Desplaines St & Jackson Blvd          15539  41.885637 -87.641823
# 48            Clinton St & Jackson Blvd            638  41.861267 -87.656625
# 49                Evanston Civic Center            661  42.057044 -87.686554
#
#     ...  ride_length        date day_of_week  year    month day  hour  \
# 0   ...          3.0  2022-01-13    Thursday  2022  January  13    11
# 1   ...          4.4  2022-01-10      Monday  2022  January  10     8
# 2   ...          4.4  2022-01-25     Tuesday  2022  January  25     4
# 3   ...         14.9  2022-01-04     Tuesday  2022  January   4     0
# 4   ...          6.0  2022-01-20    Thursday  2022  January  20     1
# 5   ...          3.4  2022-01-11     Tuesday  2022  January  11    18
# 6   ...         16.6  2022-01-30      Sunday  2022  January  30    18
# 7   ...         12.1  2022-01-22    Saturday  2022  January  22    12
# 8   ...         25.4  2022-01-17      Monday  2022  January  17     7
# 9   ...          7.4  2022-01-28      Friday  2022  January  28    15
# 10  ...          6.4  2022-01-11     Tuesday  2022  January  11    18
# 11  ...         12.4  2022-01-29    Saturday  2022  January  29    12
# 12  ...          9.3  2022-01-02      Sunday  2022  January   2    17
# 13  ...          6.9  2022-01-20    Thursday  2022  January  20    22
# 14  ...         10.0  2022-01-08    Saturday  2022  January   8     5
# 15  ...          0.5  2022-01-14      Friday  2022  January  14     5
# 16  ...          1.7  2022-01-12   Wednesday  2022  January  12    14
# 17  ...          5.0  2022-01-31      Monday  2022  January  31    12
# 18  ...          4.9  2022-01-28      Friday  2022  January  28    17
# 19  ...          9.3  2022-01-19   Wednesday  2022  January  19    21
# 20  ...         25.8  2022-01-24      Monday  2022  January  24    15
# 21  ...         23.2  2022-01-13    Thursday  2022  January  13    12
# 22  ...          4.7  2022-01-18     Tuesday  2022  January  18     8
# 23  ...         14.0  2022-01-25     Tuesday  2022  January  25    14
# 24  ...          7.1  2022-01-10      Monday  2022  January  10     6
# 25  ...         10.8  2022-01-22    Saturday  2022  January  22    15
# 26  ...          5.1  2022-01-03      Monday  2022  January   3     0
# 27  ...          6.8  2022-01-31      Monday  2022  January  31    18
# 28  ...          7.6  2022-01-15    Saturday  2022  January  15    17
# 29  ...         24.0  2022-01-24      Monday  2022  January  24    10
# 30  ...         10.7  2022-01-27    Thursday  2022  January  27    17
# 31  ...         25.9  2022-01-18     Tuesday  2022  January  18    17
# 32  ...          9.5  2022-01-27    Thursday  2022  January  27    11
# 33  ...          7.5  2022-01-15    Saturday  2022  January  15    12
# 34  ...         12.5  2022-01-14      Friday  2022  January  14    10
# 35  ...         14.8  2022-01-13    Thursday  2022  January  13    16
# 36  ...         13.5  2022-01-12   Wednesday  2022  January  12    16
# 37  ...          2.6  2022-01-29    Saturday  2022  January  29     6
# 38  ...          9.1  2022-01-12   Wednesday  2022  January  12    22
# 39  ...          2.7  2022-01-19   Wednesday  2022  January  19    12
# 40  ...          2.8  2022-01-04     Tuesday  2022  January   4    15
# 41  ...         17.0  2022-01-20    Thursday  2022  January  20    16
# 42  ...         15.7  2022-01-22    Saturday  2022  January  22    15
# 43  ...         39.0  2022-01-12   Wednesday  2022  January  12     9
# 44  ...          7.8  2022-01-04     Tuesday  2022  January   4     9
# 45  ...          7.2  2022-01-19   Wednesday  2022  January  19    16
# 46  ...         13.4  2022-01-02      Sunday  2022  January   2    16
# 47  ...          4.5  2022-01-13    Thursday  2022  January  13    12
# 48  ...         12.4  2022-01-17      Monday  2022  January  17    10
# 49  ...          1.5  2022-01-26   Wednesday  2022  January  26    15
#
#    time_of_day  season  avg_ride_duration
# 0      Morning  Winter          17.124021
# 1      Morning  Winter          17.124021
# 2        Night  Winter          17.124021
# 3        Night  Winter          17.124021
# 4        Night  Winter          17.124021
# 5      Evening  Winter          17.124021
# 6      Evening  Winter          17.124021
# 7    Afternoon  Winter          17.124021
# 8      Morning  Winter          17.124021
# 9    Afternoon  Winter          17.124021
# 10     Evening  Winter          17.124021
# 11   Afternoon  Winter          17.124021
# 12   Afternoon  Winter          17.124021
# 13     Evening  Winter          17.124021
# 14       Night  Winter          17.124021
# 15       Night  Winter          17.124021
# 16   Afternoon  Winter          17.124021
# 17   Afternoon  Winter          17.124021
# 18   Afternoon  Winter          17.124021
# 19     Evening  Winter          17.124021
# 20   Afternoon  Winter          17.124021
# 21   Afternoon  Winter          17.124021
# 22     Morning  Winter          17.124021
# 23   Afternoon  Winter          17.124021
# 24     Morning  Winter          17.124021
# 25   Afternoon  Winter          17.124021
# 26       Night  Winter          17.124021
# 27     Evening  Winter          17.124021
# 28   Afternoon  Winter          17.124021
# 29     Morning  Winter          17.124021
# 30   Afternoon  Winter          17.124021
# 31   Afternoon  Winter          17.124021
# 32     Morning  Winter          17.124021
# 33   Afternoon  Winter          17.124021
# 34     Morning  Winter          17.124021
# 35   Afternoon  Winter          17.124021
# 36   Afternoon  Winter          17.124021
# 37     Morning  Winter          17.124021
# 38     Evening  Winter          17.124021
# 39   Afternoon  Winter          17.124021
# 40   Afternoon  Winter          17.124021
# 41   Afternoon  Winter          17.124021
# 42   Afternoon  Winter          17.124021
# 43     Morning  Winter          17.124021
# 44     Morning  Winter          17.124021
# 45   Afternoon  Winter          17.124021
# 46   Afternoon  Winter          17.124021
# 47   Afternoon  Winter          17.124021
# 48     Morning  Winter          17.124021
# 49   Afternoon  Winter          17.124021
#
# [50 rows x 23 columns]
